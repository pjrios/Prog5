# %% [markdown]
# # Yolo v11 y arduino
#
# En este proyecto, se explora la integración de YOLO v11, un avanzado modelo para la detección de objetos, con Arduino. La combinación de ambas tecnologías permite desarrollar sistemas que reconocen objetos **en tiempo real** y luego envían esta información a un dispositivo embebido para su utilización.

# %%
from ultralytics import YOLO
import serial
import time
import cv2

# %% [markdown]
# ## Importar modelo

# %%
# Load YOLOv11 model
model = YOLO("yolo11n.pt")  # Update with your model's actual path

# %% [markdown]
# ## Definir funciones y variables

# %%
Puerto = "COM9"
# Configuración del puerto serial (ajusta el puerto a tu configuración)
arduino = serial.Serial(port=Puerto, baudrate=9600, timeout=1)

time.sleep(2)  # Esperar a que Arduino esté listo

def enviar_comando(comando):
    arduino.write(f"{comando}\n".encode())  # Enviar comando
    time.sleep(0.5)  # Esperar por la respuesta
    respuesta = arduino.readline().decode().strip()  # Leer respuesta
    print(f"Respuesta de Arduino: {respuesta}")

# Function to process detections
def process_detections(results):
    # Iterate over each result in the results list
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls)  # Convert tensor to int
            confidence = float(box.conf)  # Convert tensor to float
            bbox = box.xyxy.tolist()  # Convert tensor to list
            name = result.names[class_id]

            # Print detection information
            print(f"Name: {name}")
            #print(f"Class: {class_id}, Confidence: {confidence:.2f}, BBox: {bbox}")

            # Send command if the detected object is "cat"
            #if name == "person":
            enviar_comando(name)  # Example: Send command to turn on LED

# %% [markdown]
# ## Main program

# %%
# Open the webcam
cap = cv2.VideoCapture(0)  # '0' selects the default webcam

if not cap.isOpened():
    print("Error: Could not open webcam.")
    cap.release()
    exit()

# Read frames in a loop
try:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Failed to read frame from webcam.")
            break

        # Run YOLO on the frame
        results = model(frame)  # Perform inference

        # Process detection results
        process_detections(results)

        # Draw the results on the frame
        annotated_frame = results[0].plot()  # Annotate the frame with detections

        # Display the annotated frame
        cv2.imshow("YOLOv11 Webcam", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
finally:
    # Release the webcam and close all OpenCV windows
    cap.release()
    cv2.destroyAllWindows()
    # Cerrar la conexión al final
    arduino.close()
# Out:
# 0: 480x640 1 person, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 tie, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: tie
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 cell phone, 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: cell phone
# Respuesta de Arduino: On
#
# 0: 480x640 2 persons, 2 chairs, 49.1ms
# Speed: 2.0ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: person
# Respuesta de Arduino: On
# Name: chair
# Respuesta de Arduino: On
# Name: chair
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 suitcase, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 2 suitcases, 1 chair, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
# Name: chair
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 scissors, 46.6ms
# Speed: 2.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: scissors
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 scissors, 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: scissors
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 scissors, 50.8ms
# Speed: 2.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: scissors
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 chair, 1 scissors, 42.7ms
# Speed: 2.0ms preprocess, 42.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: scissors
# Respuesta de Arduino: On
# Name: chair
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 2 suitcases, 45.9ms
# Speed: 0.9ms preprocess, 45.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 suitcase, 1 chair, 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: chair
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 suitcase, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 suitcase, 45.6ms
# Speed: 3.0ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 2 suitcases, 37.2ms
# Speed: 0.9ms preprocess, 37.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 suitcase, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 suitcase, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 suitcase, 41.0ms
# Speed: 0.9ms preprocess, 41.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 suitcase, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On
#
# 0: 480x640 1 person, 1 suitcase, 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Name: person
# Respuesta de Arduino: On
# Name: suitcase
# Respuesta de Arduino: On

# %% [markdown]
# ```c
# // Código Arduino para controlar una luz basado en comandos recibidos por serial
# // Pin conectado al LED o luz
# const int lightPin = 13;
# // Variable para almacenar el último momento en que se detectó una persona
# unsigned long lastPersonDetectedTime = 0;
# // Tiempo límite de 1 segundo (1000 ms)
# const unsigned long timeout = 10000;
#
# void setup() {
#   // Inicializa la comunicación serial a 921600 baudios
#   Serial.begin(9600);
#   // Configura el pin del LED como salida
#   pinMode(lightPin, OUTPUT);
# }
#
# void loop() {
#   // Verifica si hay datos disponibles para leer desde el puerto serial
#   if (Serial.available() > 0) {
#     // Lee el comando entrante hasta encontrar un salto de línea
#     String command = Serial.readStringUntil('\n');
#     // Elimina cualquier espacio en blanco o caracteres de nueva línea al final del comando
#     command.trim();
#     if (command == "person") {
#       // Si el comando recibido es "person"
#       digitalWrite(lightPin, HIGH); // Enciende la luz
#       lastPersonDetectedTime = millis(); // Actualiza el tiempo de la última detección
#       Serial.println("On");
#     }
#   }
#   // Apaga la luz si no se recibe el comando "person" durante 1 segundo
#   if (millis() - lastPersonDetectedTime > timeout) {
#     digitalWrite(lightPin, LOW); // Apaga la luz
#     Serial.println("Off");
#   }
# }
# ```
